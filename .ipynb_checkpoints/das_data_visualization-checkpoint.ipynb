# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

df = pd.read_csv('scrubbed_pandemic_data.csv')
df
# Out:
#       iso_code        date     location  total_cases  total_deaths  \
# 0          AFG  2019-12-31  Afghanistan          0.0           0.0
# 1          AFG  2020-02-23  Afghanistan          0.0           0.0
# 2          AFG  2020-02-25  Afghanistan          1.0           0.0
# 3          AFG  2020-03-01  Afghanistan          1.0           0.0
# 4          AFG  2020-03-03  Afghanistan          0.0           0.0
# ...        ...         ...          ...          ...           ...
# 43809      ZWE  2020-10-15     Zimbabwe       8055.0         231.0
# 43810      ZWE  2020-10-16     Zimbabwe       8075.0         231.0
# 43811      ZWE  2020-10-17     Zimbabwe       8099.0         231.0
# 43812      ZWE  2020-10-18     Zimbabwe       8110.0         231.0
# 43813      ZWE  2020-10-19     Zimbabwe       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita  human_development_index
# 0                  0.00    38928341        1803.987                    0.498
# ...

# %%
figure(figsize=(20, 8), dpi=80)
plt.plot(df['location'], df['population'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
