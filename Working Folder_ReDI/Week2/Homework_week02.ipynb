# %% [markdown]
# # Homework:
#
# This week, there are two homework tasks, of which the web scraping task is optional.

# %% [markdown]
# ## API Task
#
# 1. Go to https://spoonacular.com/food-api and get familiar with the information you can get from this API. Find out how to authenticate a request to this API.
# 2. Retrieve 150 random recipes
# 4. Create a .csv file with the following headers:
# - vegetarian
# - glutenFree
# - dairyFree
# - veryHealthy
# - healthScore
# - aggregateLikes
# - id
# - title
# - pricePerServing
# - readyInMinutes
# - servings
# - sourceUrl
# - there is a list of nutrients, create two columns per nutrient: one stating the amount and one the percentOfDailyNeeds. The name is e.g. "seleniumAmount" and "seleniumPercentOfDailyNeed"
#
# **Handin:**
# - your notebook (.ipynb file)
# - your .csv file
#
# or
#
# - link to GitHub folder containing both files
#
# **Hints:**
# - In order to retrieve the information you are looking for, you need to add a query to the request url, which is described in the API documentation
# - Please be aware, that the use of this API is restricted. The documentation states that you have a certain amount of API calls & responses each day. You can see your used points in the response header. Keep an eye on it when developing your script.
# - To avoid repeated calls to an API, use another cell in your notebook, once you stored the correct response information in a variable. This is one situation in which jupyter notebooks are very convenient.
# - Keep the .csv file, we might want to work with it in the future, but don't worry if you didn't manage, we'll provide you with a data set.

# %%
import requests
import spoonacular
import csv
import pandas as pd

# %%
endpoint_batch1 = "https://api.spoonacular.com/recipes/random?number=100&apiKey=d5f28412151545ddb2db42c4e5495546"
# endpoint_batch2 = "https://api.spoonacular.com/recipes/random?number=50&apiKey=d5f28412151545ddb2db42c4e5495546"


r = requests.get(endpoint_batch1)
results = r.json()

filename = "spoonacular_receipes_150_asm.csv"
header = ['vegetarian', 'glutenFree', 'dairyFree', 'veryHealthy', 'healthScore', 'aggregateLikes', 'id', 'title', 'pricePerServing','readyInMinutes','servings','sourceUrl']

# %%
with open("spoonacular_receipes_150_asm.csv", 'w') as f:
    receipe_data = results['recipes']
    csv_writer = csv.writer(f)
    csv_writer.writerow(header)

    for single_receipe in receipe_data:
        attr_list = []
        # Writing data of CSV file
        attr_list.append(single_receipe['vegetarian'])
        attr_list.append(single_receipe['glutenFree'])
        attr_list.append(single_receipe['dairyFree'])
        attr_list.append(single_receipe['veryHealthy'])
        attr_list.append(single_receipe['healthScore'])
        attr_list.append(single_receipe['aggregateLikes'])
        attr_list.append(single_receipe['id'])
        attr_list.append(single_receipe['title'])
        attr_list.append(single_receipe['pricePerServing'])
        attr_list.append(single_receipe['readyInMinutes'])
        attr_list.append(single_receipe['servings'])
        attr_list.append(single_receipe['sourceUrl'])
        csv_writer.writerow(attr_list)

# %%
df = pd.read_csv("spoonacular_receipes_150_asm.csv")

# %%
for i, row in df.iterrows(): 
    id = row['id']
    print(id)

    nutrient_ep = f"https://api.spoonacular.com/recipes/{id}/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546"
    print(nutrient_ep)
    r_nutri = requests.get(nutrient_ep)
    nutri_results = r_nutri.json()
    for value in nutri_results.values():
        if 'list' in str(type(value)):
            if row['id'] == id:
                for item in value:
                    df.loc[df['id'] == id, item['title']+"-Amount"] = item['amount']   
                    df.loc[df['id'] == id, item['title']+"-PercentOfDailyNeed"] = item['percentOfDailyNeeds']
                df.to_csv("spoonacular_receipes_150_asm.csv", index=True) 
            else:
                break

print('Done!!!!')
# Out:
# 648709
# https://api.spoonacular.com/recipes/648709/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 636558
# https://api.spoonacular.com/recipes/636558/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 641559
# https://api.spoonacular.com/recipes/641559/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 661121
# https://api.spoonacular.com/recipes/661121/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 633265
# https://api.spoonacular.com/recipes/633265/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 633338
# https://api.spoonacular.com/recipes/633338/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 640275
# https://api.spoonacular.com/recipes/640275/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 716198
# https://api.spoonacular.com/recipes/716198/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 715573
# https://api.spoonacular.com/recipes/715573/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 639866
# https://api.spoonacular.com/recipes/639866/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 636359
# https://api.spoonacular.com/recipes/636359/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 655523
# https://api.spoonacular.com/recipes/655523/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 650751
# https://api.spoonacular.com/recipes/650751/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 652819
# https://api.spoonacular.com/recipes/652819/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 632071
# https://api.spoonacular.com/recipes/632071/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 641659
# https://api.spoonacular.com/recipes/641659/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 656846
# https://api.spoonacular.com/recipes/656846/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 646825
# https://api.spoonacular.com/recipes/646825/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 632279
# https://api.spoonacular.com/recipes/632279/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 637042
# https://api.spoonacular.com/recipes/637042/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 638257
# https://api.spoonacular.com/recipes/638257/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 639644
# https://api.spoonacular.com/recipes/639644/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 652417
# https://api.spoonacular.com/recipes/652417/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 659927
# https://api.spoonacular.com/recipes/659927/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 634434
# https://api.spoonacular.com/recipes/634434/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 636080
# https://api.spoonacular.com/recipes/636080/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 639891
# https://api.spoonacular.com/recipes/639891/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 651389
# https://api.spoonacular.com/recipes/651389/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 715523
# https://api.spoonacular.com/recipes/715523/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 663858
# https://api.spoonacular.com/recipes/663858/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 636589
# https://api.spoonacular.com/recipes/636589/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 632590
# https://api.spoonacular.com/recipes/632590/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 635869
# https://api.spoonacular.com/recipes/635869/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 654835
# https://api.spoonacular.com/recipes/654835/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 640062
# https://api.spoonacular.com/recipes/640062/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 639629
# https://api.spoonacular.com/recipes/639629/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 716423
# https://api.spoonacular.com/recipes/716423/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 665182
# https://api.spoonacular.com/recipes/665182/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 631785
# https://api.spoonacular.com/recipes/631785/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 637625
# https://api.spoonacular.com/recipes/637625/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 655890
# https://api.spoonacular.com/recipes/655890/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 639492
# https://api.spoonacular.com/recipes/639492/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 644681
# https://api.spoonacular.com/recipes/644681/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 729366
# https://api.spoonacular.com/recipes/729366/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 716296
# https://api.spoonacular.com/recipes/716296/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 632819
# https://api.spoonacular.com/recipes/632819/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 1005367
# https://api.spoonacular.com/recipes/1005367/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 641794
# https://api.spoonacular.com/recipes/641794/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 642096
# https://api.spoonacular.com/recipes/642096/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 651326
# https://api.spoonacular.com/recipes/651326/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 715477
# https://api.spoonacular.com/recipes/715477/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 715469
# https://api.spoonacular.com/recipes/715469/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 661447
# https://api.spoonacular.com/recipes/661447/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 1045245
# https://api.spoonacular.com/recipes/1045245/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 715567
# https://api.spoonacular.com/recipes/715567/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 636768
# https://api.spoonacular.com/recipes/636768/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 651729
# https://api.spoonacular.com/recipes/651729/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 715421
# https://api.spoonacular.com/recipes/715421/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 632928
# https://api.spoonacular.com/recipes/632928/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 632103
# https://api.spoonacular.com/recipes/632103/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 661758
# https://api.spoonacular.com/recipes/661758/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 661557
# https://api.spoonacular.com/recipes/661557/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 641893
# https://api.spoonacular.com/recipes/641893/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 637222
# https://api.spoonacular.com/recipes/637222/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 715574
# https://api.spoonacular.com/recipes/715574/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 645696
# https://api.spoonacular.com/recipes/645696/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 639672
# https://api.spoonacular.com/recipes/639672/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 649808
# https://api.spoonacular.com/recipes/649808/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 715515
# https://api.spoonacular.com/recipes/715515/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 642178
# https://api.spoonacular.com/recipes/642178/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 715511
# https://api.spoonacular.com/recipes/715511/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 632140
# https://api.spoonacular.com/recipes/632140/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 644387
# https://api.spoonacular.com/recipes/644387/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 639031
# https://api.spoonacular.com/recipes/639031/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 658579
# https://api.spoonacular.com/recipes/658579/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 716361
# https://api.spoonacular.com/recipes/716361/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 641651
# https://api.spoonacular.com/recipes/641651/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 631755
# https://api.spoonacular.com/recipes/631755/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 716427
# https://api.spoonacular.com/recipes/716427/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 633921
# https://api.spoonacular.com/recipes/633921/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 716367
# https://api.spoonacular.com/recipes/716367/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 655668
# https://api.spoonacular.com/recipes/655668/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 716297
# https://api.spoonacular.com/recipes/716297/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 633340
# https://api.spoonacular.com/recipes/633340/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 792072
# https://api.spoonacular.com/recipes/792072/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 632015
# https://api.spoonacular.com/recipes/632015/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 716279
# https://api.spoonacular.com/recipes/716279/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 765011
# https://api.spoonacular.com/recipes/765011/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 637187
# https://api.spoonacular.com/recipes/637187/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 645418
# https://api.spoonacular.com/recipes/645418/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 659782
# https://api.spoonacular.com/recipes/659782/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 637932
# https://api.spoonacular.com/recipes/637932/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 635561
# https://api.spoonacular.com/recipes/635561/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 782619
# https://api.spoonacular.com/recipes/782619/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 715602
# https://api.spoonacular.com/recipes/715602/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 637067
# https://api.spoonacular.com/recipes/637067/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 633139
# https://api.spoonacular.com/recipes/633139/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 632874
# https://api.spoonacular.com/recipes/632874/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 636325
# https://api.spoonacular.com/recipes/636325/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# 798956
# https://api.spoonacular.com/recipes/798956/nutritionWidget.json?apiKey=d5f28412151545ddb2db42c4e5495546
# Done!!!!

# %% [markdown]
# ## Additional task: Web Scraping
# We want to create a list of all currently open data analytics jobs in Copenhagen:
# - job title
# - company
# - link to the job advert
# - publication data
#
# Since we cannot find an API or any other open dataset, we decide to scrape the publicly available homepage https://www.jobindex.dk/
#
# The information is available here: https://www.jobindex.dk/jobsoegning/storkoebenhavn?q=%27Data+Analyst%27
#
# Handin:
# **Handin:**
# - your notebook (.ipynb file)
# - your .csv file
#
# or
#
# - link to GitHub folder containing all the homework week 2 files (including the API call - files)
#
# **Hints**
# - Make sure to make use of the developer tools of your browser to inspect the website you are scraping and find the tags you need.
# - Make your scraper robust, so that it does not crash in case of unexpectet values in a record.
# - Be mindful of not overloading the website with calls, you might get blocked. You can use  `from time import sleep` and integrate the following line into your script for a 3 second break in repeated requests to the website: `sleep(3)`
# - The results are not all displayed on one page. Scrape the results from the first page first and then figure out how to get the results from the subsequent pages.
